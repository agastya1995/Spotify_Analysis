# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_d = pd.read_csv(r'/home/agastya/Documents/Python/Praxis/ML/Personal Practice/Spotify_Project/data/data_w_genres.csv')
genres = pd.read_csv(r'/home/agastya/Documents/Python/Praxis/ML/Personal Practice/Spotify_Project/data/data_by_genres.csv')
main_d.head()
# Out:
#    Unnamed: 0                  artists  acousticness  danceability  \
# 0           0         Francisco Canaro      0.983072      0.654711
# 1           1          Frédéric Chopin      0.989961      0.340087
# 2           2     Ludwig van Beethoven      0.955019      0.340157
# 3           3  Wolfgang Amadeus Mozart      0.962084      0.353895
# 4           4    Johann Sebastian Bach      0.958405      0.354224
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  177776.513454  0.292622          0.490675  0.201118 -11.733373
# 1  251871.948502  0.106874          0.876899  0.155677 -22.575578
# 2  439361.331606  0.153176          0.690770  0.164078 -20.107704
# 3  327808.037306  0.138348          0.514837  0.187091 -20.214154
# 4  203461.757872  0.201932          0.744322  0.165837 -20.936518
#
#    speechiness       tempo   valence  popularity  key  mode  count  \
# 0     0.111007  123.608786  0.746469    0.054257    2     1   2267
# 1     0.042913   90.977772  0.203644    5.748127    1     1   1068
# 2     0.055550  104.833536  0.260255    5.237306    0     1    965
# 3     0.067756  108.594920  0.332855    9.624870    7     1    965
# 4     0.048844  106.551869  0.570526   14.704669    7     1    921
#
#                                               genres
# 0                         ['tango', 'vintage tango']
# 1  ['classical', 'early romantic era', 'polish cl...
# 2  ['classical', 'classical era', 'early romantic...
# 3                     ['classical', 'classical era']
# 4  ['baroque', 'classical', 'early music', 'germa...

# %%
main_d.genres.value_counts()
# Out:
# []                                                                                                                                             9546
# ['movie tunes']                                                                                                                                  76
# ['background music']                                                                                                                             75
# ['show tunes']                                                                                                                                   64
# ['classical piano']                                                                                                                              61
#                                                                                                                                                ...
# ['british singer-songwriter', 'cambridgeshire indie', 'chamber pop', 'indie anthem-folk', 'indie folk', 'indie soul', 'neo mellow']               1
# ['blues rock', 'canadian metal', 'hard rock']                                                                                                     1
# ['classic garage rock', 'folk rock', 'freakbeat', 'psychedelic rock']                                                                             1
# ['album rock', 'art rock', 'canterbury scene', 'instrumental rock', 'jazz fusion', 'neo-progressive', 'progressive rock', 'symphonic rock']       1
# ['destroy techno', 'electro house']                                                                                                               1
# Name: genres, Length: 10164, dtype: int64

# %%
main_d.dtypes
# Out:
# Unnamed: 0            int64
# artists              object
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# liveness            float64
# loudness            float64
# speechiness         float64
# tempo               float64
# valence             float64
# popularity          float64
# key                   int64
# mode                  int64
# count                 int64
# genres               object
# dtype: object

# %%
import re
pattern = re.compile(r'\w+\s*?\w+', re.IGNORECASE)
main_d['genre'] = main_d['genres'].map(lambda x: re.findall(pattern, x))

# %%
genres.head()
# Out:
#                    genres  acousticness  danceability   duration_ms    energy  \
# 0  21st century classical      0.983000      0.218500  1.496130e+05  0.018350
# 1                   432hz      0.485070      0.330000  1.059273e+06  0.463084
# 2                      []      0.686395      0.516830  2.305397e+05  0.397491
# 3              a cappella      0.666036      0.576732  1.961439e+05  0.334535
# 4                abstract      0.352395      0.489100  3.429772e+05  0.509300
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.874000  0.112800 -37.256000     0.038750   69.526500  0.062900
# 1          0.480393  0.118862 -17.099000     0.086288  125.227125  0.217675
# 2          0.202883  0.221324 -12.773475     0.109871  111.933224  0.513905
# 3          0.028486  0.128292 -13.011177     0.106782  112.461108  0.502521
# 4          0.788033  0.122317 -13.812100     0.044157  124.176500  0.354130
#
#    popularity  key  mode
# 0   40.500000    1     1
# 1   52.125000    6     1
# 2   21.556669    7     1
# 3   38.786415   11     1
# 4   41.600000    1     1

# %%
main_d.head()
# Out:
#    Unnamed: 0                  artists  acousticness  danceability  \
# 0           0         Francisco Canaro      0.983072      0.654711
# 1           1          Frédéric Chopin      0.989961      0.340087
# 2           2     Ludwig van Beethoven      0.955019      0.340157
# 3           3  Wolfgang Amadeus Mozart      0.962084      0.353895
# 4           4    Johann Sebastian Bach      0.958405      0.354224
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  177776.513454  0.292622          0.490675  0.201118 -11.733373
# 1  251871.948502  0.106874          0.876899  0.155677 -22.575578
# 2  439361.331606  0.153176          0.690770  0.164078 -20.107704
# 3  327808.037306  0.138348          0.514837  0.187091 -20.214154
# 4  203461.757872  0.201932          0.744322  0.165837 -20.936518
#
#    speechiness       tempo   valence  popularity  key  mode  count  \
# 0     0.111007  123.608786  0.746469    0.054257    2     1   2267
# 1     0.042913   90.977772  0.203644    5.748127    1     1   1068
# 2     0.055550  104.833536  0.260255    5.237306    0     1    965
# 3     0.067756  108.594920  0.332855    9.624870    7     1    965
# 4     0.048844  106.551869  0.570526   14.704669    7     1    921
#
#                                               genres  \
# 0                         ['tango', 'vintage tango']
# 1  ['classical', 'early romantic era', 'polish cl...
# 2  ['classical', 'classical era', 'early romantic...
# 3                     ['classical', 'classical era']
# 4  ['baroque', 'classical', 'early music', 'germa...
#
#                                                genre
# 0                             [tango, vintage tango]
# 1  [classical, early romantic, era, polish classi...
# 2    [classical, classical era, early romantic, era]
# 3                         [classical, classical era]
# 4  [baroque, classical, early music, german baroque]

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# %%
print(genres.shape)
genres.columns
# Out:
# (2617, 14)
# Index(['genres', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key', 'mode'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler(feature_range=(0,1))
genres_scaled = sc.fit_transform(genres.loc[:,'acousticness':'mode'])
genres_scaled = pd.DataFrame(genres_scaled, columns=['acousticness', 'danceability', 'duration_ms', 'energy',
       'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
       'valence', 'popularity', 'key', 'mode'])
genres_scaled = pd.concat([genres['genres'],genres_scaled],axis=1)
genres_scaled.head()
# Out:
#                    genres  acousticness  danceability  duration_ms    energy  \
# 0  21st century classical      0.986948      0.205117     0.064129  0.015577
# 1                   432hz      0.487017      0.324323     0.633516  0.461794
# 2                      []      0.689151      0.524065     0.114784  0.395982
# 3              a cappella      0.668711      0.588107     0.093254  0.332817
# 4                abstract      0.353809      0.494418     0.185162  0.508165
#
#    instrumentalness  liveness  loudness  speechiness     tempo   valence  \
# 0          0.881048  0.096609  0.012319     0.024025  0.131469  0.059535
# 1          0.484267  0.103074  0.548587     0.075356  0.490659  0.216710
# 2          0.204519  0.212330  0.663666     0.100822  0.404932  0.517536
# 3          0.028716  0.113128  0.657342     0.097486  0.408336  0.505975
# 4          0.794388  0.106757  0.636034     0.029864  0.483884  0.355282
#
#    popularity       key  mode
# 0    0.476471  0.090909   1.0
# 1    0.613235  0.545455   1.0
# 2    0.253608  0.636364   1.0
# 3    0.456311  1.000000   1.0
# 4    0.489412  0.090909   1.0

# %%
plt.figure(figsize=(10, 7))

sch.dendrogram(sch.linkage(genres_scaled.loc[:,'acousticness':'mode']),
            orientation='top',
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()

# %% [markdown]
# Davies-Bouldin index is an internal evaluation method for clustering algorithms. Lower values indicate tighter clusters that
# are better separated. (d1 + d2)/d3.
# d1 : avg intra cluster distance
# d2 : avg intra cluster distance
# d3 : Inter Cluster distance

# %%
from sklearn.metrics import davies_bouldin_score, silhouette_score

# %%
cluster_range = range(200,600,20)
Davies = []
silhouette = []

for i in cluster_range:
    cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='ward')
    
    cluster.fit_predict(genres_scaled.loc[:,'acousticness':'mode'])
    
    labels = cluster.labels_
    Davies.append(davies_bouldin_score(genres_scaled.loc[:,'acousticness':'mode'], labels))
    silhouette.append(silhouette_score(genres_scaled.loc[:,'acousticness':'mode'], labels))

# %%
sns.lineplot(x=cluster_range, y=Davies)
plt.show()

# %%
sns.lineplot(x=cluster_range, y=silhouette)

# %%
cluster = AgglomerativeClustering(n_clusters=300, affinity='euclidean', linkage='ward')
    
cluster.fit_predict(genres_scaled.loc[:,'acousticness':'mode'])
    
genres_scaled['labels'] = cluster.labels_

# %%
d = genres_scaled.groupby('labels')['genres'].count().reset_index()

# %%
d[d['genres']==1].count()
# Out:
# labels    11
# genres    11
# dtype: int64
